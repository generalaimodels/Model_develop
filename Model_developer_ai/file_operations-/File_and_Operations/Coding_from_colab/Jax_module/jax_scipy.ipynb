# %% [markdown]
# | Module           | Function                                      | Description                                                       | Usage                                                                                                       |
# |------------------|-----------------------------------------------|-------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------|
# | jax.scipy.fft    | dct                                           | Return the Discrete Cosine Transform of arbitrary type sequence x | `from jax.scipy.fft import dct`                                                                           |
# |                  | dctn                                          | Return multidimensional Discrete Cosine Transform                  | `from jax.scipy.fft import dctn`                                                                          |
# |                  | idct                                          | Return the Inverse Discrete Cosine Transform of a sequence         | `from jax.scipy.fft import idct`                                                                          |
# |                  | idctn                                         | Return multidimensional Inverse Discrete Cosine Transform          | `from jax.scipy.fft import idctn`                                                                         |
# | jax.scipy.integrate | trapezoid                                    | Integrate using the composite trapezoidal rule                     | `from jax.scipy.integrate import trapezoid`                                                               |
# | jax.scipy.linalg | block_diag                                    | Create a block diagonal matrix from provided arrays                | `from jax.scipy.linalg import block_diag`                                                                 |
# |                  | cho_factor                                    | Compute the Cholesky decomposition of a matrix                     | `from jax.scipy.linalg import cho_factor`                                                                 |
# |                  | cho_solve                                     | Solve linear equations using Cholesky factorization                | `from jax.scipy.linalg import cho_solve`                                                                  |
# |                  | cholesky                                      | Compute the Cholesky decomposition of a matrix                     | `from jax.scipy.linalg import cholesky`                                                                   |
# |                  | det                                           | Compute the determinant of a matrix                                | `from jax.scipy.linalg import det`                                                                        |
# |                  | eigh                                          | Solve eigenvalue problem for a complex matrix                      | `from jax.scipy.linalg import eigh`                                                                       |
# |                  | eigh_tridiagonal                              | Solve eigenvalue problem for a real symmetric tridiagonal matrix   | `from jax.scipy.linalg import eigh_tridiagonal`                                                           |
# |                  | expm                                          | Compute the matrix exponential of an array                         | `from jax.scipy.linalg import expm`                                                                       |
# |                  | expm_frechet                                  | Frechet derivative of the matrix exponential                        | `from jax.scipy.linalg import expm_frechet`                                                               |
# |                  | funm                                          | Evaluate a matrix function specified by a callable                 | `from jax.scipy.linalg import funm`                                                                       |
# |                  | hessenberg                                    | Compute Hessenberg form of a matrix                                | `from jax.scipy.linalg import hessenberg`                                                                 |
# |                  | inv                                           | Compute the inverse of a matrix                                    | `from jax.scipy.linalg import inv`                                                                        |
# |                  | lu                                            | Compute LU decomposition of a matrix                                | `from jax.scipy.linalg import lu`                                                                         |
# |                  | lu_factor                                     | Compute pivoted LU decomposition of a matrix                       | `from jax.scipy.linalg import lu_factor`                                                                  |
# |                  | lu_solve                                      | Solve an equation system given LU factorization of a matrix         | `from jax.scipy.linalg import lu_solve`                                                                   |
# |                  | polar                                         | Compute the polar decomposition                                    | `from jax.scipy.linalg import polar`                                                                      |
# |                  | qr                                            | Compute QR decomposition of a matrix                                | `from jax.scipy.linalg import qr`                                                                         |
# |                  | rsf2csf                                       | Convert real Schur form to complex Schur form                      | `from jax.scipy.linalg import rsf2csf`                                                                    |
# |                  | schur                                         | Compute Schur decomposition of a matrix                             | `from jax.scipy.linalg import schur`                                                                      |
# |                  | solve                                         | Solve linear equation set for unknown x                            | `from jax.scipy.linalg import solve`                                                                      |
# |                  | solve_triangular                              | Solve equation a x = b for x, assuming a is a triangular matrix    | `from jax.scipy.linalg import solve_triangular`                                                           |
# |                  | sqrtm                                         | Compute matrix square root                                         | `from jax.scipy.linalg import sqrtm`                                                                      |
# |                  | svd                                           | Singular Value Decomposition                                       | `from jax.scipy.linalg import svd`                                                                        |
# |                  | toeplitz                                      | Construct a Toeplitz matrix                                        | `from jax.scipy.linalg import toeplitz`                                                                   |
# | jax.scipy.ndimage | map_coordinates                              | Map input array to new coordinates by interpolation                | `from jax.scipy.ndimage import map_coordinates`                                                           |
# | jax.scipy.optimize | minimize                                     | Minimization of scalar function of one or more variables           | `from jax.scipy.optimize import minimize`                                                                 |
# |                  | OptimizeResults                               | Object holding optimization results                                | `from jax.scipy.optimize import OptimizeResults`                                                          |

# %% [markdown]
# Here's a tabular representation of how to import and use functions from the `jax.scipy.signal`, `jax.scipy.spatial.transform`, `jax.scipy.sparse.linalg`, and `jax.scipy.special` modules:
#
# | Module                           | Function            | Description                                                          | Usage                                                      |
# |----------------------------------|---------------------|----------------------------------------------------------------------|------------------------------------------------------------|
# | jax.scipy.signal                | fftconvolve         | Convolve two N-dimensional arrays using FFT                         | `from jax.scipy.signal import fftconvolve`                 |
# |                                  | convolve            | Convolve two N-dimensional arrays                                   | `from jax.scipy.signal import convolve`                    |
# |                                  | convolve2d          | Convolve two 2-dimensional arrays                                   | `from jax.scipy.signal import convolve2d`                  |
# |                                  | correlate           | Cross-correlate two N-dimensional arrays                            | `from jax.scipy.signal import correlate`                   |
# |                                  | correlate2d         | Cross-correlate two 2-dimensional arrays                            | `from jax.scipy.signal import correlate2d`                 |
# |                                  | csd                 | Estimate the cross power spectral density using Welch's method       | `from jax.scipy.signal import csd`                         |
# |                                  | istft               | Perform the inverse Short Time Fourier transform (iSTFT)            | `from jax.scipy.signal import istft`                       |
# |                                  | stft                | Compute the Short Time Fourier Transform (STFT)                     | `from jax.scipy.signal import stft`                        |
# |                                  | welch               | Estimate power spectral density using Welch's method                | `from jax.scipy.signal import welch`                       |
# | jax.scipy.spatial.transform    | Rotation            | Rotation in 3 dimensions                                            | `from jax.scipy.spatial.transform import Rotation`         |
# |                                  | Slerp               | Spherical Linear Interpolation of Rotations                         | `from jax.scipy.spatial.transform import Slerp`            |
# | jax.scipy.sparse.linalg        | bicgstab            | Use Bi-Conjugate Gradient Stable iteration to solve Ax = b           | `from jax.scipy.sparse.linalg import bicgstab`            |
# |                                  | cg                  | Use Conjugate Gradient iteration to solve Ax = b                    | `from jax.scipy.sparse.linalg import cg`                  |
# |                                  | gmres               | GMRES solves the linear system A x = b for x, given A and b         | `from jax.scipy.sparse.linalg import gmres`               |
# | jax.scipy.special              | beta                | Beta function                                                        | `from jax.scipy.special import beta`                      |
# |                                  | betainc             | Regularized incomplete beta function                                | `from jax.scipy.special import betainc`                   |
# |                                  | betaln              | Natural logarithm of absolute value of beta function                | `from jax.scipy.special import betaln`                    |
# |                                  | digamma             | The digamma function                                                | `from jax.scipy.special import digamma`                   |
# |                                  | erf                 | Error function of complex argument                                   | `from jax.scipy.special import erf`                       |
# |                                  | erfc                | Complementary error function, 1 - erf(x)                            | `from jax.scipy.special import erfc`                      |
# |                                  | erfinv              | Inverse of the error function                                        | `from jax.scipy.special import erfinv`                    |
# |                                  | exp1                | Exponential integral E1                                             | `from jax.scipy.special import exp1`                      |
# |                                  | expi                | Exponential integral Ei                                             | `from jax.scipy.special import expi`                      |
# |                                  | expit               | Expit (a.k.a. logistic sigmoid) ufunc for ndarrays                  | `from jax.scipy.special import expit`                     |
# |                                  | expn                | Generalized exponential integral En                                  | `from jax.scipy.special import expn`                      |
# |                                  | factorial           | The factorial of a number or array of numbers                       | `from jax.scipy.special import factorial`                 |
# |                                  | gamma               | Gamma function                                                      | `from jax.scipy.special import gamma`                     |
# |                                  | gammainc            | Regularized lower incomplete gamma function                         | `from jax.scipy.special import gammainc`                  |
# |                                  | gammaln             | Logarithm of the absolute value of the gamma function               | `from jax.scipy.special import gammaln`                   |
# |                                  | hyp1f1              | Confluent hypergeometric function 1F1                                | `from jax.scipy.special import hyp1f1`                    |
# |                                  | log_ndtr            | Log Normal distribution function                                    | `from jax.scipy.special import log_ndtr`                  |
# |                                  | logit               | Logit ufunc for ndarrays                                            | `from jax.scipy.special import logit`                     |
# |                                  | logsumexp           | Compute the log of the sum of exponentials of input elements        | `from jax.scipy.special import logsumexp`                 |
# |                                  | ndtr                | Normal distribution function                                         | `from jax.scipy.special import ndtr`                      |
# |                                  | ndtri               | Inverse of the CDF of the Normal distribution function              | `from jax.scipy.special import ndtri`                     |
# |                                  | poch                | Pochhammer symbol                                                   | `from jax.scipy.special import poch`                      |
# |                                  | polygamma           | Polygamma functions                                                 | `from jax.scipy.special import polygamma`                 |
# |                                  | spence              | Spence's function, also known as the dilogarithm for real values    | `from jax.scipy.special import spence`                    |
# |                                  | sph_harm            | Computes the spherical harmonics                                    | `from jax.scipy.special import sph_harm`                  |
# |                                  | zeta                | Riemann or Hurwitz zeta function                                    | `from jax.scipy.special import zeta`                      |
# |                                  | kl_div              | Elementwise function for computing Kullback-Leibler divergence      | `from jax.scipy.special import kl_div`                    |
# |                                  | rel_entr            | Elementwise function for computing relative entropy                 | `from jax.scipy.special import rel_entr`                  |

# %% [markdown]
# Below is a tabular representation of how to import and use functions from the mentioned modules in `jax.scipy.stats`:
#
# | Module                           | Function            | Description                                                          | Usage                                                      |
# |----------------------------------|---------------------|----------------------------------------------------------------------|------------------------------------------------------------|
# | jax.scipy.stats                | mode                | LAX-backend implementation of scipy.stats._stats_py.mode()          | `from jax.scipy.stats import mode`                 |
# |                                  | rankdata            | Assign ranks to data, dealing with ties appropriately               | `from jax.scipy.stats import rankdata`             |
# |                                  | sem                 | LAX-backend implementation of scipy.stats._stats_py.sem()           | `from jax.scipy.stats import sem`                  |
# | jax.scipy.stats.bernoulli      | logpmf              | Log of the probability mass function at k of the given RV          | `from jax.scipy.stats.bernoulli import logpmf`     |
# |                                  | pmf                 | Probability mass function at k of the given RV                      | `from jax.scipy.stats.bernoulli import pmf`        |
# |                                  | cdf                 | Cumulative distribution function of the given RV                   | `from jax.scipy.stats.bernoulli import cdf`        |
# |                                  | ppf                 | Percent point function (inverse of cdf) at q of the given RV       | `from jax.scipy.stats.bernoulli import ppf`        |
# | jax.scipy.stats.beta           | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.beta import logpdf`          |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.beta import pdf`             |
# |                                  | cdf                 | Cumulative distribution function of the given RV                   | `from jax.scipy.stats.beta import cdf`             |
# |                                  | logcdf              | Log of the cumulative distribution function at x of the given RV   | `from jax.scipy.stats.beta import logcdf`          |
# |                                  | sf                  | Survival function (1 - cdf) at x of the given RV                   | `from jax.scipy.stats.beta import sf`              |
# |                                  | logsf               | Log of the survival function of the given RV                       | `from jax.scipy.stats.beta import logsf`           |
# | jax.scipy.stats.betabinom      | logpmf              | Log of the probability mass function at k of the given RV          | `from jax.scipy.stats.betabinom import logpmf`     |
# |                                  | pmf                 | Probability mass function at k of the given RV                      | `from jax.scipy.stats.betabinom import pmf`        |
# | jax.scipy.stats.binom          | logpmf              | Log of the probability mass function at k of the given RV          | `from jax.scipy.stats.binom import logpmf`         |
# |                                  | pmf                 | Probability mass function at k of the given RV                      | `from jax.scipy.stats.binom import pmf`            |
# | jax.scipy.stats.cauchy         | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.cauchy import logpdf`        |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.cauchy import pdf`           |
# |                                  | cdf                 | Cumulative distribution function of the given RV                   | `from jax.scipy.stats.cauchy import cdf`           |
# |                                  | logcdf              | Log of the cumulative distribution function at x of the given RV   | `from jax.scipy.stats.cauchy import logcdf`        |
# |                                  | sf                  | Survival function (1 - cdf) at x of the given RV                   | `from jax.scipy.stats.cauchy import sf`            |
# |                                  | logsf               | Log of the survival function of the given RV                       | `from jax.scipy.stats.cauchy import logsf`         |
# |                                  | isf                 | Inverse survival function (inverse of sf) at q of the given RV     | `from jax.scipy.stats.cauchy import isf`           |
# |                                  | ppf                 | Percent point function (inverse of cdf) at q of the given RV       | `from jax.scipy.stats.cauchy import ppf`           |
# | jax.scipy.stats.chi2           | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.chi2 import logpdf`          |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.chi2 import pdf`             |
# |                                  | cdf                 | Cumulative distribution function of the given RV                   | `from jax.scipy.stats.chi2 import cdf`             |
# |                                  | logcdf              | Log of the cumulative distribution function at x of the given RV   | `from jax.scipy.stats.chi2 import logcdf`          |
# |                                  | sf                  | Survival function (1 - cdf) at x of the given RV                   | `from jax.scipy.stats.chi2 import sf`             |
# |                                  | logsf               | Log of the survival function of the given RV                       | `from jax.scipy.stats.chi2 import logsf`          |
# | jax.scipy.stats.dirichlet      | logpdf              | Log of the Dirichlet probability density function                  | `from jax.scipy.stats.dirichlet import logpdf`     |
# |                                  | pdf                 | The Dirichlet probability density function                         | `from jax.scipy.stats.dirichlet import pdf`        |
# | jax.scipy.stats.expon          | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.expon import logpdf`        |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.expon import pdf`           |
# | jax.scipy.stats.gamma          | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.gamma import logpdf`        |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.gamma import pdf`           |
# |                                  | cdf                 | Cumulative distribution function of the given RV                   | `from jax.scipy.stats.gamma import cdf`           |
# |                                  | logcdf              | Log of the cumulative distribution function at x of the given RV   | `from jax.scipy.stats.gamma import logcdf`        |
# |
# | sf                  | Survival function (1 - cdf) at x of the given RV                   | `from jax.scipy.stats.gamma import sf`            |
# |                                  | logsf               | Log of the survival function of the given RV                       | `from jax.scipy.stats.gamma import logsf`         |
# | jax.scipy.stats.gennorm        | cdf                 | Cumulative distribution function of the given RV                   | `from jax.scipy.stats.gennorm import cdf`         |
# |                                  | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.gennorm import logpdf`      |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.gennorm import pdf`         |
# | jax.scipy.stats.geom           | logpmf              | Log of the probability mass function at k of the given RV          | `from jax.scipy.stats.geom import logpmf`         |
# |                                  | pmf                 | Probability mass function at k of the given RV                      | `from jax.scipy.stats.geom import pmf`            |
# | jax.scipy.stats.laplace        | cdf                 | Cumulative distribution function of the given RV                   | `from jax.scipy.stats.laplace import cdf`         |
# |                                  | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.laplace import logpdf`      |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.laplace import pdf`         |
# | jax.scipy.stats.logistic       | cdf                 | Cumulative distribution function of the given RV                   | `from jax.scipy.stats.logistic import cdf`        |
# |                                  | isf                 | Inverse survival function (inverse of sf) at q of the given RV     | `from jax.scipy.stats.logistic import isf`        |
# |                                  | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.logistic import logpdf`     |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.logistic import pdf`        |
# |                                  | ppf                 | Percent point function (inverse of cdf) at q of the given RV       | `from jax.scipy.stats.logistic import ppf`        |
# |                                  | sf                  | Survival function (1 - cdf) at x of the given RV                   | `from jax.scipy.stats.logistic import sf`         |
# | jax.scipy.stats.multinomial    | logpmf              | Log of the Multinomial probability mass function                    | `from jax.scipy.stats.multinomial import logpmf`  |
# |                                  | pmf                 | Multinomial probability mass function                               | `from jax.scipy.stats.multinomial import pmf`     |
# | jax.scipy.stats.multivariate_normal | logpdf            | Log of the multivariate normal probability density function         | `from jax.scipy.stats.multivariate_normal import logpdf` |
# |                                      | pdf                | Multivariate normal probability density function                   | `from jax.scipy.stats.multivariate_normal import pdf`    |
# | jax.scipy.stats.nbinom          | logpmf              | Log of the probability mass function at k of the given RV          | `from jax.scipy.stats.nbinom import logpmf`       |
# |                                  | pmf                 | Probability mass function at k of the given RV                      | `from jax.scipy.stats.nbinom import pmf`          |
# | jax.scipy.stats.norm            | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.norm import logpdf`         |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.norm import pdf`            |
# |                                  | cdf                 | Cumulative distribution function of the given RV                   | `from jax.scipy.stats.norm import cdf`            |
# |                                  | logcdf              | Log of the cumulative distribution function at x of the given RV   | `from jax.scipy.stats.norm import logcdf`         |
# |                                  | ppf                 | Percent point function (inverse of cdf) at q of the given RV       | `from jax.scipy.stats.norm import ppf`            |
# |                                  | sf                  | Survival function (1 - cdf) at x of the given RV                   | `from jax.scipy.stats.norm import sf`             |
# |                                  | logsf               | Log of the survival function of the given RV                       | `from jax.scipy.stats.norm import logsf`          |
# |                                 | isf                 | Inverse survival function (inverse of sf) at q of the given RV     | `from jax.scipy.stats.norm import isf`            |
# | jax.scipy.stats.pareto          | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.pareto import logpdf`      |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.pareto import pdf`         |
# | jax.scipy.stats.poisson         | logpmf              | Log of the probability mass function at k of the given RV          | `from jax.scipy.stats.poisson import logpmf`     |
# |                                  | pmf                 | Probability mass function at k of the given RV                      | `from jax.scipy.stats.poisson import pmf`        |
# | jax.scipy.stats.t               | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.t import logpdf`           |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.t import pdf`              |
# | jax.scipy.stats.truncnorm       | cdf                 | Cumulative distribution function of the given RV                   | `from jax.scipy.stats.truncnorm import cdf`      |
# |                                  | logcdf              | Log of the cumulative distribution function at x of the given RV   | `from jax.scipy.stats.truncnorm import logcdf`   |
# |                                  | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.truncnorm import logpdf`  |
# |                                  | logsf               | Log of the survival function of the given RV                       | `from jax.scipy.stats.truncnorm import logsf`   |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.truncnorm import pdf`      |
# |                                  | sf                  | Survival function (1 - cdf) at x of the given RV                   | `from jax.scipy.stats.truncnorm import sf`       |
# | jax.scipy.stats.uniform         | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.uniform import logpdf`     |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.uniform import pdf`        |
# |                                  | cdf                 | Cumulative distribution function of the given RV                   | `from jax.scipy.stats.uniform import cdf`        |
# |                                  | ppf                 | Percent point function (inverse of cdf) at q of the given RV       | `from jax.scipy.stats.uniform import ppf`        |
# | jax.scipy.stats.gaussian_kde    | gaussian_kde        | Representation of a kernel-density estimate using Gaussian kernels | `from jax.scipy.stats.gaussian_kde import gaussian_kde` |
# |                                  | evaluate            | Evaluate the estimated pdf on a set of points                      | `from jax.scipy.stats.gaussian_kde import evaluate` |
# |                                  | integrate_gaussian  | Multiply estimated density by a multivariate Gaussian and integrate| `from jax.scipy.stats.gaussian_kde import integrate_gaussian` |
# |                                  | integrate_box_1d   | Computes the integral of a 1D pdf between two bounds               | `from jax.scipy.stats.gaussian_kde import integrate_box_1d` |
# |                                  | integrate_kde       | Computes the integral of the product of this kernel density estimate| `from jax.scipy.stats.gaussian_kde import integrate_kde` |
# |                                  | resample            | Randomly sample a dataset from the estimated pdf                    | `from jax.scipy.stats.gaussian_kde import resample` |
# |                                  | pdf                 | Evaluate the estimated pdf on a provided set of points             | `from jax.scipy.stats.gaussian_kde import pdf` |
# |                                  | logpdf              | Evaluate the log of the estimated pdf on a provided set of points  | `from jax.scipy.stats.gaussian_kde import logpdf` |
# | jax.scipy.stats.vonmises        | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.vonmises import logpdf`   |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.vonmises import pdf`      |
# | jax.scipy.stats.wrapcauchy      | logpdf              | Log of the probability density function at x of the given RV       | `from jax.scipy.stats.wrapcauchy import logpdf` |
# |                                  | pdf                 | Probability density function at x of the given RV                  | `from jax.scipy.stats.wrapcauchy import pdf`    |
#
# These import statements allow you to access and utilize the functions provided by the respective modules within `jax.scipy.stats`. Make sure you replace the function names with the ones you want to use in your code.

# %% [markdown]
# | Module                     | Function          | Description                                                             | Import Statement                                   |
# |----------------------------|-------------------|-------------------------------------------------------------------------|----------------------------------------------------|
# | Key Creation & Manipulation| PRNGKey           | Create a pseudo-random number generator (PRNG) key given an integer seed| `from jax.random import PRNGKey`                  |
# |                            | key               | Create a pseudo-random number generator (PRNG) key given an integer seed| `from jax.random import key`                      |
# |                            | key_data          | Recover the bits of key data underlying a PRNG key array                | `from jax.random import key_data`                 |
# |                            | wrap_key_data     | Wrap an array of key data bits into a PRNG key array                    | `from jax.random import wrap_key_data`            |
# |                            | fold_in           | Folds in data to a PRNG key to form a new PRNG key                       | `from jax.random import fold_in`                  |
# |                            | split             | Splits a PRNG key into num new keys by adding a leading axis            | `from jax.random import split`                    |
# |                            | clone             | Clone a key for reuse                                                   | `from jax.random import clone`                    |
# | Random Samplers           | ball              | Sample uniformly from the unit Lp ball                                   | `from jax.random import ball`                     |
# |                            | bernoulli         | Sample Bernoulli random values with given shape and mean                 | `from jax.random import bernoulli`                |
# |                            | beta              | Sample Beta random values with given shape and float dtype               | `from jax.random import beta`                     |
# |                            | binomial          | Sample Binomial random values with given shape and float dtype           | `from jax.random import binomial`                 |
# |                            | bits              | Sample uniform bits in the form of unsigned integers                     | `from jax.random import bits`                     |
# |                            | categorical       | Sample random values from categorical distributions                      | `from jax.random import categorical`              |
# |                            | cauchy            | Sample Cauchy random values with given shape and float dtype            | `from jax.random import cauchy`                   |
# |                            | chisquare         | Sample Chisquare random values with given shape and float dtype         | `from jax.random import chisquare`                |
# |                            | choice            | Generates a random sample from a given array                              | `from jax.random import choice`                   |
# |                            | dirichlet         | Sample Dirichlet random values with given shape and float dtype          | `from jax.random import dirichlet`                |
# |                            | double_sided_maxwell | Sample from a double sided Maxwell distribution                      | `from jax.random import double_sided_maxwell`     |
# |                            | exponential       | Sample Exponential random values with given shape and float dtype        | `from jax.random import exponential`              |
# |                            | f                 | Sample F-distribution random values with given shape and float dtype     | `from jax.random import f`                        |
# |                            | gamma             | Sample Gamma random values with given shape and float dtype              | `from jax.random import gamma`                    |
# |                            | generalized_normal| Sample from the generalized normal distribution                          | `from jax.random import generalized_normal`       |
# |                            | geometric         | Sample Geometric random values with given shape and float dtype          | `from jax.random import geometric`                |
# |                            | gumbel            | Sample Gumbel random values with given shape and float dtype             | `from jax.random import gumbel`                   |
# |                            | laplace           | Sample Laplace random values with given shape and float dtype            | `from jax.random import laplace`                  |
# |                            | loggamma          | Sample log-gamma random values with given shape and float dtype          | `from jax.random import loggamma`                 |
# |                            | logistic          | Sample logistic random values with given shape and float dtype           | `from jax.random import logistic`                 |
# |                            | lognormal         | Sample lognormal random values with given shape and float dtype          | `from jax.random import lognormal`                |
# |                            | maxwell           | Sample from a one sided Maxwell distribution                             | `from jax.random import maxwell`                  |
# |                            | multivariate_normal | Sample multivariate normal random values with given mean and covariance  | `from jax.random import multivariate_normal`     |
# |                            | normal            | Sample standard normal random values with given shape and float dtype    | `from jax.random import normal`                   |
# |                            | orthogonal        | Sample uniformly from the orthogonal group O(n)                           | `from jax.random import orthogonal`               |
# |                            | pareto            | Sample Pareto random values with given shape and float dtype             | `from jax.random import pareto`                   |
# |                            | permutation       | Returns a randomly permuted array or range                                | `from jax.random import permutation`              |
# |                            | poisson           | Sample Poisson random values with given shape and integer dtype           | `from jax.random import poisson`                  |
# |                            | rademacher        | Sample from a Rademacher distribution                                    | `from jax.random import rademacher`               |
# |                            | randint           | Sample uniform random values in [minval, maxval) with given shape/dtype  | `from jax.random import randint`                  |
# |                            | rayleigh          | Sample Rayleigh random values with given shape and float dtype           | `from jax.random import rayleigh`                 |
# |                            | t                 | Sample Student's t random values with given shape and float dtype         | `from jax.random import t`                        |
# |                            | triangular        | Sample Triangular random values with given shape and float dtype         | `from jax.random import triangular`               |
# |                            | truncated_normal  | Sample truncated standard normal random values with given shape and dtype| `from jax.random import truncated_normal`         |
# |                            | uniform           | Sample uniform random values in [minval, maxval) with given shape/dtype  | `from jax.random import uniform`                  |
# |                            | wald              | Sample Wald random values with given shape and float dtype               | `from jax.random import wald`                     |
# |                            | weibull_min       | Sample from a Weibull distribution                                        | `from jax.random import weibull_min`              |
