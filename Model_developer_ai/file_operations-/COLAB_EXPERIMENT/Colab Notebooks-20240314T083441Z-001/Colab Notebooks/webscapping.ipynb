# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

def tell_jokes(query):
    # Initialize the Firefox webdriver
    browser = webdriver.Firefox()

    # Open a search engine (Yahoo in this case)
    browser.get('http://www.yahoo.com')
    assert 'Yahoo' in browser.title

    # Find the search box and enter the user's query
    search_box = browser.find_element(By.NAME, 'p')
    search_box.send_keys(query + ' jokes' + Keys.RETURN)

    # Wait for the search results to load
    browser.implicitly_wait(10)  # Adjust the wait time as needed

    # Find all search result links
    search_results = browser.find_elements(By.XPATH, "//a[@href]")

    # Extract and print the URLs
    for result in search_results:
        url = result.get_attribute("href")
        if url:
            print(url)

    # Quit the browser
    browser.quit()

# Ask the user for a joke category or keyword
user_input = 'women'

# Tell jokes based on the user's input
tell_jokes(user_input)

# %%
import json
import os
import stat
import time
from typing import List
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service
import requests
import tarfile
import zipfile
from io import BytesIO

# Function to download geckodriver and set the executable path
def download_geckodriver(driver_path: str):
    # URL to get the latest geckodriver release
    geckodriver_url = "https://github.com/mozilla/geckodriver/releases/download/v0.34.0/geckodriver-v0.34.0-linux-aarch64.tar.gz"

    # Make the request and check if the status code is 200 OK
    response = requests.get(geckodriver_url, stream=True)
    if response.status_code == 200:
        # Extract the contents of the tar.gz file
        tarball = BytesIO(response.content)
        with zipfile.ZipFile(tarball) as z:
            z.extractall(path=os.path.dirname(driver_path))

        # Make the geckodriver executable
        os.chmod(driver_path, stat.S_IRWXU)
    else:
        print("Error downloading geckodriver, HTTP Status Code: ", response.status_code)
        return None
def search_locations(query: str, driver_path: str) -> List[str]:
    """
    Perform an advanced search for locations using Selenium.

    Args:
        query (str): The search query for locations.
        driver_path (str): The path to the Firefox driver executable.

    Returns:
        List[str]: A list of location details.
    """
    # Set up Firefox options
    firefox_options = Options()
    firefox_options.add_argument("--headless")  # Run in headless mode

    # Set up Firefox service
    firefox_service = Service(executable_path=driver_path)

    # Create a new Firefox driver instance
    driver = webdriver.Firefox(service=firefox_service, options=firefox_options)

    try:
        # Navigate to the search page
        driver.get("https://www.google.com/search")

        # Find the search input field and enter the query
        search_input = driver.find_element(By.NAME, "search_input")
        search_input.send_keys(query)

        # Find the search button and click it
        search_button = driver.find_element(By.ID, "search_button")
        search_button.click()

        # Wait for the search results to load
        time.sleep(20)

        # Find all the location elements
        location_elements = driver.find_elements(By.CLASS_NAME, "location")

        # Extract the location details
        locations = []
        for element in location_elements:
            location_details = element.text
            locations.append(location_details)

        return locations

    finally:
        # Close the browser
        driver.quit()


# Example usage
query = "Restaurants in New York"
download_path = "/content/geckodriver"  # Replace with the desired download path

# Download geckodriver if it doesn't exist
driver_path = os.path.join(download_path, "geckodriver.exe")
if not os.path.exists(driver_path):
    driver_path = download_geckodriver(download_path)
    if driver_path is None:
        print("Failed to download geckodriver. Exiting.")
        exit(1)
else:
    print("geckodriver is already downloaded.")

results = search_locations(query, driver_path)

# Save the results to a JSON file
with open("location_results.json", "w") as file:
    json.dump(results, file, indent=2)

# Print the location details
print("Location Details:")
for location in results:
    print(location)
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-15-67b2027de30b> in <cell line: 91>()
#      90 driver_path = os.path.join(download_path, "geckodriver.exe")
#      91 if not os.path.exists(driver_path):
# ---> 92     driver_path = download_geckodriver(download_path)
#      93     if driver_path is None:
#      94         print("Failed to download geckodriver. Exiting.")
#
# <ipython-input-15-67b2027de30b> in download_geckodriver(driver_path)
#      23         # Extract the contents of the tar.gz file
#      24         tarball = BytesIO(response.content)
# ---> 25         with zipfile.ZipFile(tarball) as z:
#      26             z.extractall(path=os.path.dirname(driver_path))
#      27
#
# /usr/lib/python3.10/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1267         try:
# ...

# %%
import os
import stat
import requests
import zipfile
from io import BytesIO

# Function to download geckodriver and set the executable path
def download_geckodriver(driver_path: str):
    # URL to get the latest geckodriver release
    geckodriver_url = "https://github.com/mozilla/geckodriver/releases/download/v0.34.0/geckodriver-v0.34.0-linux-aarch64.tar.gz"

    # Make the request and check if the status code is 200 OK
    response = requests.get(geckodriver_url, stream=True)
    if response.status_code == 200:
        # Extract the contents of the tar.gz file
        tarball = BytesIO(response.content)
        with zipfile.ZipFile(tarball) as z:
            z.extractall(path=os.path.dirname(driver_path))

        # Make the geckodriver executable
        os.chmod(driver_path, stat.S_IRWXU)
    else:
        print("Error downloading geckodriver, HTTP Status Code: ", response.status_code)
        return None

# Define the path where you want to save the geckodriver executable
driver_path = "/content/"

# Download geckodriver if it doesn't exist
if not os.path.exists(driver_path):
    download_geckodriver(driver_path)
else:
    print("geckodriver is already downloaded.")

# You can now use driver_path in your Selenium code
# Out:
# geckodriver is already downloaded.

# %%
import json
import os
import stat
import time
from typing import List
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service
import requests
import tarfile
from io import BytesIO

# Function to download geckodriver and set the executable path
def download_geckodriver(driver_path: str):
    # URL to get the latest geckodriver release
    geckodriver_url = "https://github.com/mozilla/geckodriver/releases/download/v0.34.0/geckodriver-v0.34.0-linux-aarch64.tar.gz"

    # Make the request and check if the status code is 200 OK
    response = requests.get(geckodriver_url, stream=True)
    if response.status_code == 200:
        # Extract the contents of the tar.gz file
        tarball = BytesIO(response.content)
        with zipfile.ZipFile(tarball) as z:
            z.extractall(path=os.path.dirname(driver_path))

        # Make the geckodriver executable
        os.chmod(driver_path, stat.S_IRWXU)
    else:
        print("Error downloading geckodriver, HTTP Status Code: ", response.status_code)
        return None

def search_locations(query: str, driver_path: str) -> List[str]:
    """
    Perform an advanced search for locations using Selenium.

    Args:
        query (str): The search query for locations.
        driver_path (str): The path to the Firefox driver executable.

    Returns:
        List[str]: A list of location details.
    """
    # Set up Firefox options
    firefox_options = Options()
    firefox_options.add_argument("--headless")  # Run in headless mode

    # Set up Firefox service
    firefox_service = Service(executable_path=driver_path)

    # Create a new Firefox driver instance
    driver = webdriver.Firefox(service=firefox_service, options=firefox_options)

    try:
        # Navigate to the search page
        driver.get("https://www.google.com/search")

        # Find the search input field and enter the query
        search_input = driver.find_element(By.NAME, "search_input")
        search_input.send_keys(query)

        # Find the search button and click it
        search_button = driver.find_element(By.ID, "search_button")
        search_button.click()

        # Wait for the search results to load
        time.sleep(20)

        # Find all the location elements
        location_elements = driver.find_elements(By.CLASS_NAME, "location")

        # Extract the location details
        locations = []
        for element in location_elements:
            location_details = element.text
            locations.append(location_details)

        return locations

    finally:
        # Close the browser
        driver.quit()

# Example usage
query = "Restaurants in New York"
driver_path = "/content/geckodriver"  # Replace with the desired path to save geckodriver

# Download geckodriver if it doesn't exist
if not os.path.exists(driver_path):
    download_geckodriver(driver_path)
else:
    print("geckodriver is already downloaded.")

results = search_locations(query, driver_path)

# Save the results to a JSON file
with open("location_results.json", "w") as file:
    json.dump(results, file, indent=2)

# Print the location details
print("Location Details:")
for location in results:
    print(location)
# Out:
# geckodriver is already downloaded.
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-14-9f44d9d67255> in <cell line: 94>()
#      92     print("geckodriver is already downloaded.")
#      93
# ---> 94 results = search_locations(query, driver_path)
#      95
#      96 # Save the results to a JSON file
#
# <ipython-input-14-9f44d9d67255> in search_locations(query, driver_path)
#      50
#      51     # Create a new Firefox driver instance
# ---> 52     driver = webdriver.Firefox(service=firefox_service, options=firefox_options)
#      53
#      54     try:
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, options, service, keep_alive)
#      67
#      68         try:
# ---> 69             super().__init__(command_executor=executor, options=options)
#      70         except Exception:
# ...

# %%
# !ls -lahs
# Out:
# total 16K
# 4.0K drwxr-xr-x 1 root root 4.0K Mar  7 14:32 .
# 4.0K drwxr-xr-x 1 root root 4.0K Mar  9 12:07 ..
# 4.0K drwxr-xr-x 4 root root 4.0K Mar  7 14:31 .config
# 4.0K drwxr-xr-x 1 root root 4.0K Mar  7 14:32 sample_data

# %%
# !pip install -q selenium
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 32.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.2/460.2 kB 45.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.3 MB/s eta 0:00:00

# %%
import json
import time
from typing import List
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service

def search_locations(query: str, driver_path: str) -> List[str]:
    """
    Perform an advanced search for locations using Selenium.

    Args:
        query (str): The search query for locations.
        driver_path (str): The path to the Firefox driver executable.

    Returns:
        List[str]: A list of location details.
    """
    # Set up Firefox options
    firefox_options = Options()
    firefox_options.add_argument("--headless")  # Run in headless mode

    # Set up Firefox service
    firefox_service = Service(executable_path=driver_path)

    # Create a new Firefox driver instance
    driver = webdriver.Firefox(service=firefox_service, options=firefox_options)

    try:
        # Navigate to the search page
        driver.get("https://www.google.com/search")

        # Find the search input field and enter the query
        search_input = driver.find_element(By.NAME, "search_input")
        search_input.send_keys(query)

        # Find the search button and click it
        search_button = driver.find_element(By.ID, "search_button")
        search_button.click()

        # Wait for the search results to load
        time.sleep(20)

        # Find all the location elements
        location_elements = driver.find_elements(By.CLASS_NAME, "location")

        # Extract the location details
        locations = []
        for element in location_elements:
            location_details = element.text
            locations.append(location_details)

        return locations

    finally:
        # Close the browser
        driver.quit()

# Example usage
query = "Restaurants in New York"
driver_path = "/content/"  # Replace with the actual path to geckodriver

results = search_locations(query, driver_path)

# Save the results to a JSON file
with open("location_results.json", "w") as file:
    json.dump(results, file, indent=2)

# Print the location details
print("Location Details:")
for location in results:
    print(location)
# Out:
# ---------------------------------------------------------------------------
# NoSuchDriverException                     Traceback (most recent call last)
# <ipython-input-10-61ad79d86679> in <cell line: 64>()
#      62 driver_path = "/content/"  # Replace with the actual path to geckodriver
#      63
# ---> 64 results = search_locations(query, driver_path)
#      65
#      66 # Save the results to a JSON file
#
# <ipython-input-10-61ad79d86679> in search_locations(query, driver_path)
#      26
#      27     # Create a new Firefox driver instance
# ---> 28     driver = webdriver.Firefox(service=firefox_service, options=firefox_options)
#      29
#      30     try:
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, options, service, keep_alive)
#      57         options = options if options else Options()
#      58
# ---> 59         self.service.path = DriverFinder.get_path(self.service, options)
#      60         self.service.start()
# ...
