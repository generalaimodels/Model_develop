# %%
# Import necessary libraries
import numpy as np
from sklearn.manifold import TSNE
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Create a synthetic dataset with 5 classes (clusters) in a 50-dimensional space
X, data_class = make_classification(n_samples=1000, n_features=50, n_informative=5,
                                    n_redundant=0, n_classes=5, n_clusters_per_class=1)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, data_class, test_size=0.2, random_state=42)

# Convert labels to categorical one-hot encoding
y_train = to_categorical(y_train, num_classes=5)
y_test = to_categorical(y_test, num_classes=5)

# Create a simple deep learning model
model = Sequential()
model.add(Dense(64, input_dim=50, activation='relu'))
model.add(Dense(5, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32)

# Use the trained model to transform the test set into feature representations
features = model.predict(X_test)

# Initialize t-SNE
tsne = TSNE(n_components=2, random_state=0)

# Apply t-SNE to the features
reduced = tsne.fit_transform(features)

# Plot the transformed features and color them by their true labels
plt.scatter(reduced[:, 0], reduced[:, 1], c=np.argmax(y_test, axis=1), cmap='rainbow')

# Display the plot
plt.show()
# Out:
# Epoch 1/20
# 25/25 [==============================] - 1s 2ms/step - loss: 1.8271 - accuracy: 0.2113
# Epoch 2/20
# 25/25 [==============================] - 0s 2ms/step - loss: 1.5067 - accuracy: 0.3562
# Epoch 3/20
# 25/25 [==============================] - 0s 2ms/step - loss: 1.2908 - accuracy: 0.4762
# Epoch 4/20
# 25/25 [==============================] - 0s 2ms/step - loss: 1.1263 - accuracy: 0.5838
# Epoch 5/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.9993 - accuracy: 0.6463
# Epoch 6/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.8968 - accuracy: 0.7013
# Epoch 7/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.8118 - accuracy: 0.7362
# Epoch 8/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.7424 - accuracy: 0.7538
# Epoch 9/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6850 - accuracy: 0.7837
# Epoch 10/20
# ...

# %%
# !pip install umap-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.3 MB/s eta 0:00:00
# ...
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=a7265ca3f75306c708e05a9415c92ada1e735ed4dcab65445bf8ecda1bed05d6
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built umap-learn
# ...

# %%
# Import necessary libraries
import numpy as np
from umap import UMAP
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# Create a synthetic dataset with 5 classes (clusters) in a 50-dimensional space
X, data_class = make_classification(n_samples=1000, n_features=50, n_informative=5,
                                    n_redundant=0, n_classes=5, n_clusters_per_class=1)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, data_class, test_size=0.2, random_state=42)

# Convert labels to categorical one-hot encoding
y_train = to_categorical(y_train, num_classes=5)
y_test = to_categorical(y_test, num_classes=5)

# Create a simple deep learning model
model = Sequential()
model.add(Dense(64, input_dim=50, activation='relu'))
model.add(Dense(5, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32)

# Use the trained model to transform the test set into feature representations
features = model.predict(X_test)

# Initialize UMAP
umap = UMAP(n_components=2, random_state=0)

# Apply UMAP to the features
reduced = umap.fit_transform(features)

# Plot the transformed features and color them by their true labels
plt.scatter(reduced[:, 0], reduced[:, 1], c=np.argmax(y_test, axis=1), cmap='rainbow')

# Display the plot
plt.show()
# Out:
# Epoch 1/20
# 25/25 [==============================] - 1s 2ms/step - loss: 1.7825 - accuracy: 0.2425
# Epoch 2/20
# 25/25 [==============================] - 0s 2ms/step - loss: 1.4360 - accuracy: 0.4162
# Epoch 3/20
# 25/25 [==============================] - 0s 2ms/step - loss: 1.2057 - accuracy: 0.5362
# Epoch 4/20
# 25/25 [==============================] - 0s 2ms/step - loss: 1.0444 - accuracy: 0.6438
# Epoch 5/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.9257 - accuracy: 0.7000
# Epoch 6/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.8343 - accuracy: 0.7387
# Epoch 7/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.7626 - accuracy: 0.7638
# Epoch 8/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.7041 - accuracy: 0.7937
# Epoch 9/20
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6574 - accuracy: 0.8112
# Epoch 10/20
# ...

# %% [markdown]
# | Parameter                         | How to Use                                  | Explanation                                                                     |
# |-----------------------------------|---------------------------------------------|---------------------------------------------------------------------------------|
# | `--dataset_name`                  | Type: str, Default: None                    | The name of the dataset to use (via the datasets library).                       |
# | `--dataset_config_name`           | Type: str, Default: None                    | The configuration name of the dataset to use (via the datasets library).         |
# | `--train_file`                    | Type: str, Default: None                    | A csv, txt or a json file containing the training data.                          |
# | `--validation_file`               | Type: str, Default: None                    | A csv, txt or a json file containing the validation data.                        |
# | `--validation_split_percentage`   | Default: 5                                | The percentage of the train set used as a validation set in case there's no validation split. |
# | `--model_name_or_path`            | Type: str, Default: None                    | Path to pretrained model or model identifier from huggingface.co/models.          |
# | ...                               | ...                                         | ...                                                                             |
# | `--hub_token`                     | Type: str                                   | The token to use to push to the Model Hub.                                       |
# | `--trust_remote_code`             | Type: bool, Default: False                  | Whether or not to allow for custom models defined on the Hub in their own modeling files. This option should only be set to `True` for repositories you trust and in which you have read the code, as it will execute code present on the Hub on your local machine. |
# | `--checkpointing_steps`           | Type: str                                   | Whether the various states should be saved at the end of every n steps, or 'epoch' for each epoch. |
# | `--resume_from_checkpoint`        | Type: str                                   | If the training should continue from a checkpoint folder.                         |
# | `--with_tracking`                 | Action: store_true                          | Whether to enable experiment trackers for logging.                               |
# | `--report_to`                     | Type: str, Default: "tensorboard"           | The integration to report the results and logs to. Supported platforms are "tensorboard", "wandb", "comet_ml", and "clearml". Use "all" (default) to report to all integrations. Only applicable when `--with_tracking` is passed. |
# | `--low_cpu_mem_usage`             | Action: store_true                          | It is an option to create the model as an empty shell, then only materialize its parameters when the pretrained weights are loaded. If passed, LLM loading time and RAM consumption will be benefited. |
# | ...                               | ...                                         | ...                                                                             |
# | `--adapter_name_or_path`          | Type: str, Default: None                    | The LoRA adapter checkpoint. Set None if you want to fine-tune from LoftQ. Specify a path if you want to evaluate. |
# | `--force_adapter_download`        | Action: store_true                          | If passed, force downloading of adapter even if it exists in the cache.        |
# | `--report_to_all`                 | Action: store_true                          | Report results and logs to all integrations.                                   |
# | `--dataloader_num_workers`        | Type: int, Default: 0                       | The number of workers to use for data loading.                                  |
# | `--dataloader_pin_memory`         | Action: store_true                          | If passed, pin memory in DataLoader.                                           |
# | `--use_stable_layer_order`        | Action: store_true                          | If passed, use the order of layers stable across different runs.                |
# | `--push_to_hub_model_id`          | Type: str                                   | The name of the repository to keep in sync with the local `output_dir`.         |
# | `--load_best_model_at_end`        | Action: store_true                          | If passed, model will be loaded from the model with the best metric during evaluation at the end of training. |
# | `--metric_for_best_model`         | Type: str                                   | The metric to use for monitoring and saving the best model.                     |
# | `--greater_is_better`             | Action: store_true                          | If passed, the metric for the best model is higher-is-better, else lower-is-better. |
# | ...                               | ...                                         | ...                                                                             |
# | `--wandb_kwargs`                  | Type: str, Default: None                    | Pass additional arguments to W&B.                                              |
# | `--wandb_run_name`                | Type: str, Default: None                    | Name of the W&B run.                                                            |
# | `--resume_from_checkpoint`        | Type: str, Default: None                    | If the training should continue from a checkpoint folder.                       |
# | `--run_name`                      | Type: str, Default: None                    | An optional descriptor for the run.                                             |

# %%
from datasets import load_dataset
datset_name=''
dataset = load_dataset("fka/awesome-chatgpt-prompts")
print(list(dataset.keys()))
print('dataset',dataset)
print("train",str(list(dataset.keys())[0]))
print('colums:',dataset[str(list(dataset.keys())[0])].column_names)
print("feature:",dataset[str(list(dataset.keys())[0])].features)

# %%
from datasets import load_dataset

def preprocess_dataset(dataset_name):
    # Load a dataset
    dataset = load_dataset(dataset_name)

    # Function to preprocess an example based on detected feature types
    def preprocess_function(example):
        new_example = {}
        # Loop over all features in the example
        for feature_name, feature_value in example.items():
            if isinstance(feature_value, str):  # For text features
                # Apply text preprocessing like tokenization, lowercasing, etc.
                new_example[feature_name] = feature_value.lower()  # Example operation
            elif isinstance(feature_value, list):  # For categorical features
                if isinstance(feature_value[0], int):  # Label encoded list
                    # Convert numeric labels to strings if names are provided in the feature
                    label_feature = dataset["train"].features[feature_name]
                    if hasattr(label_feature, 'names'):
                        new_example[feature_name] = [label_feature.names[label] for label in feature_value]
                    else:
                        new_example[feature_name] = feature_value  # Unchanged
                else:
                    # Handle other list data types if necessary
                    pass
            else:  # For numerical or other types of features
                # Apply numerical preprocessing like normalization, scaling, etc.
                new_example[feature_name] = feature_value  # Example operation

        return new_example

    # Apply the preprocessing function to all splits in the dataset
    processed_dataset = dataset.map(preprocess_function, batched=True, num_proc=1)

    return processed_dataset

# Replace 'some_specific_name' with the actual name of the dataset you want to load
dataset_name = "LDJnr/Capybara"
processed_dataset = preprocess_dataset(dataset_name)

# Display the processed dataset and the first example of the train split
print(processed_dataset)
print(len(processed_dataset["train"]))

# %%
processed_dataset["train"][0]
