# %%
import re

# List of YouTube video URLs
video_urls = [
       "https://www.youtube.com/watch?v=-FLphqS4LYg",
       "https://www.youtube.com/watch?v=JTpDCoxZdv8",
       "https://www.youtube.com/watch?v=BO0S4YEHgC0",
       "https://www.youtube.com/watch?v=8dwrE0OCq40",
       "https://www.youtube.com/watch?v=W3XKSVjiwfM",
       "https://www.youtube.com/watch?v=aFAE45SNRSA",
       "https://www.youtube.com/watch?v=GnO4cOx_wFQ",
       "https://www.youtube.com/watch?v=zqGW6x_5N0k",
       "https://www.youtube.com/watch?v=aXDRdI-cSR4",
       "https://www.youtube.com/watch?v=iMNjuGWuCWU",
       "https://www.youtube.com/watch?v=XrI1TIZ-KIs",
       "https://www.youtube.com/watch?v=GnO4cOx_wFQ",
       "https://www.youtube.com/watch?v=Iju38nOI9cg",
       "https://www.youtube.com/watch?v=LGYPb-Zz2Es",
       "https://www.youtube.com/watch?v=6p572-y0TUM",
       "https://www.youtube.com/watch?v=yXv-28PothY",
       "https://www.youtube.com/watch?v=-BSlkzQT--0",
       "https://www.youtube.com/watch?v=mqDPAI8Pt28",
       "https://www.youtube.com/watch?v=fmdTZtNQQJI",
       "https://www.youtube.com/watch?v=hYFzyK9ExuM"
]

# Function to extract video IDs from YouTube URLs
def extract_video_ids(video_urls):
    video_ids = []
    for url in video_urls:
        # Extract video ID using regular expression
        match = re.search(r"v=([A-Za-z0-9_-]+)", url)
        if match:
            video_id = match.group(1)
            video_ids.append(video_id)
    return video_ids

# Extract video IDs
extracted_ids = extract_video_ids(video_urls)
print(extracted_ids)  # Display extracted video IDs

# %%
extracted_ids=['4A4W03qUTsw', 'gs-IDg-FoIQ', 'eC6Hd1hFvos', 'eTieetk2dSw', 'g68qlo9Izf0', 'Us5ZFp16PaU', '1WSUfWojoe0', '7mOD9kgqRf0', 'mye-UOkAliQ', 'Q9zv369Ggfk', 't9S6ApYMAQw', 'DcBC4yGHV4Q', 'psR6kMjDttM', '2PlPqSc3jM0', 'v1R8uPqjNAU', 's8ZFyqx7mHo', 'YVWxbHJakgg', 'lNd1R-Fuiuo', 'pRq2Fx4kYQI', 'bOS929yCkGE']

# %%
from IPython.display import YouTubeVideo

# List of YouTube video IDs


# Function to display YouTube videos
def display_videos(video_ids):
    for vid in video_ids:
        display(YouTubeVideo(vid, width=600, height=400))

# Display the videos in the notebook
display_videos(extracted_ids)
