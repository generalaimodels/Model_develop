# %%
# !rm -rf /content/sample_data

# %%
# !pip install -q transformers accelerate evaluate deepspeed tqdm datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 44.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 34.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !python /content/drive/MyDrive/Fine_tuning_LLMS/generalised_fine_tuning.py
# Out:
# 2024-02-26 16:47:25.767159: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 16:47:25.767216: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 16:47:25.768770: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 16:47:27.019273: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Total no of training_parameters: 1100048384
# Total no of parameters is : 1100048384
# percantage of trainable parameters is 100.0
# FIM is not supported by tokenizer, disabling FIM
# ...

# %% [markdown]
# /content/drive/MyDrive/dataset1.csv

# %%
{'train': ['/content/drive/MyDrive/dataset1.csv', '/content/drive/MyDrive/dataset1.csv','/content/drive/MyDrive/dataset1.csv', '/content/drive/MyDrive/dataset1.csv','/content/drive/MyDrive/dataset1.csv', '/content/drive/MyDrive/dataset1.csv',],
 'test': ['/content/drive/MyDrive/dataset1.csv', '/content/drive/MyDrive/dataset1.csv','/content/drive/MyDrive/dataset1.csv', '/content/drive/MyDrive/dataset1.csv','/content/drive/MyDrive/dataset1.csv', '/content/drive/MyDrive/dataset1.csv',],
 'eval': ['/content/drive/MyDrive/dataset1.csv', '/content/drive/MyDrive/dataset1.csv','/content/drive/MyDrive/dataset1.csv', '/content/drive/MyDrive/dataset1.csv','/content/drive/MyDrive/dataset1.csv', '/content/drive/MyDrive/dataset1.csv',],
 }
