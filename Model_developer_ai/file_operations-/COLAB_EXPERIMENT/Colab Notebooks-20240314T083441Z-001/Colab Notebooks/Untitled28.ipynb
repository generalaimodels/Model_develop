# %%
# !git clone  https://github.com/ProjectNUWA/DragNUWA.git

# %%
# !cd DragNUWA
# !pwd

# %%
cd DragNUWA

# %%
# !ls -l

# %%
# !pip install -q -U -r environment.txt

# %%
# !sh /content/DragNUWA/models/Download.sh

# %%
# !python DragNUWA_demo.py

# %%
# !python /content/DragNUWA/DragNUWA_net.py

# %% [markdown]
# # Nuova sezione
