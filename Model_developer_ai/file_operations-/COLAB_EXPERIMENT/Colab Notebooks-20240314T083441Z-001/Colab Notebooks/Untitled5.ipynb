# %%
# Clone the GitHub repository
# !git clone https://github.com/microsoft/promptbench.git
# Out:
# Cloning into 'promptbench'...
# remote: Enumerating objects: 177, done.
# remote: Counting objects: 100% (177/177), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 177 (delta 84), reused 151 (delta 63), pack-reused 0
# Receiving objects: 100% (177/177), 3.41 MiB | 22.95 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
cd promptbench/
# Out:
# /content/promptbench

# %%
# Install conda package manager
# !wget -q https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# !bash Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -q
# !rm Miniconda3-py37_4.8.2-Linux-x86_64.sh
# !conda init

# Create a new conda environment from the YAML file
# !conda env create -f environment.yml
# Out:
# PREFIX=/root/miniconda3
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
# ...
