# %%
from IPython.display import YouTubeVideo, display

# List of YouTube video IDs
video_ids = [
"rcxXiLhxhsk",
"zizonToFXDs",
"VPRSBzXzavo",
"gs-IDg-FoIQ",
"iR2O2GPbB0E",
"fCUkvL0mbxI",
"Q9zv369Ggfk",
"eC6Hd1hFvos",
"dKG2hoOWpxs",
"ta7yE3W_s84",
"pRq2Fx4kYQI",
"Us5ZFp16PaU",
"yu27PWzJI_Y",
"ZwtMEF0u5cM",
"ZXiruGOCn9s",
"0SDDzQuL8m0",
"eTieetk2dSw",
"67_aMPDk2zw",
"zjkBMFhNj_g",
"hfIUstzHs9A",
"7Rd1DtG1fNg",
"PLuisK3HyjM",
"ZLbVdvOoTKM",
"IcrN_L2w0_Y",
"IPOwWNgizBI",
"V1-Hm2rNkik",
"r4kButlDLUc",
"Ku9PM26Cc2c",
"dBoQLktIkOo",
"trdcOfq4yVk",
"cMJWC-csdK4",
"ou7IswWBZbY",
"3fsn19OI_C8",
"Jd9Gu6OWUNw",
"ueU1DtFscy8",
"-IV1NTGy6Mg",
"74NSDMvYZ9Y",
"rwI1_3LdVE4",
"-Ar7kC8Ooac",
"2orLCp984HA",
"9uw3F6rndnA",
"fmnFOzmdUBE",
"_j7JEDWuqLE",
"ta7yE3W_s84",
"JaVBG7tFAU8",
"8nZZ2oQhx4E",
"nCglvjJkU8A",
"DkzbCJtFvqM",
"2MBJOuVq380",
"1PH3oDly1bc",
"_ZvnD73m40o",
"CMrHM8a3hqw",
"wtolixa9XTg",
"zJBpRn2zTco",
"7Rd1DtG1fNg",
"_6R7Ym6Vy_I",
"BJQrQT2Xfyo",
"DJimQynXZsQ",
"7uLzGRlXXDw",
"5MaWmXwxFNQ",
"VRQXIiNLdAk",
"MDA3LUKNl1E",
"JRC8DqumlaI",
"p9IxoSkvZ-M",
"jrb0G9sHaWw",
"SedGB8m2XLM",
"j6dqO2dSF9c",
"Coj72EzmX20",
"Kn7SX2Mx_Jk",
"DcBC4yGHV4Q",
"JNMVulH7fCo",
"y9Gi3UgNA3E",
"_RTN8CWFUsc",
"YVU5wAA6Txo",
"X8eQQ-Ugy9A",
"xZDB1naRUlk",
"o65ueTIk6YE",
"T-w_5T-j-dA",
"NRVaRXDoI3g",
"t2bSApmPzU4",
"3MPbjtVGt9M",
"oPS-8nKGu8U",
"xI0HHN5XKDo",
"T9XSU0pKX2E",
"fIaffWv5O5Q",
"VuUHA_zK4EM",
"SHMsdAPo2Ls",
"vmjP6LjGaag",
"2vEpMb4ofVU",
"1C3rU3fxcME",
"xQ3mZhw69bc",
"3fsn19OI_C8",
"fYyZiRi6yNE",
"JUj6tgbsKhE",
"cJsIDwK3Nok",
"KSlWkrByc0o",
"lj-LGrnh1oU",
"JhCl-GeT4jw",
"GV1eQ8HZY-Q",
"fscnJ9Qfu3E",
]

def play_video_playlist(video_list):
    for video_id in video_list:
        display(YouTubeVideo(video_id, width=640, height=360))

# Play the playlist of videos
play_video_playlist(video_ids)

# %%
# !pip install pytube

# %%
from pytube import YouTube


def download_videos(video_list):
    for video_id in video_list:
        try:
            youtube_video = YouTube(f'https://www.youtube.com/watch?v={video_id}')
            video_stream = youtube_video.streams.get_highest_resolution()
            video_stream.download(output_path='your_output_folder')  # Replace 'your_output_folder' with your desired folder path
            print(f"Video '{video_id}' downloaded successfully!")
        except Exception as e:
            print(f"Error downloading video '{video_id}': {str(e)}")

# Download videos from the playlist
download_videos(video_ids)
